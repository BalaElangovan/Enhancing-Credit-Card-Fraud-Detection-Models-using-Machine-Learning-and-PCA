# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel('creditcard_2023.xlsb')

# %%
data.head()
# Out:
#    id        V1        V2        V3        V4        V5        V6        V7  \
# 0   0 -0.260648 -0.469648  2.496266 -0.083724  0.129681  0.732898  0.519014
# 1   1  0.985100 -0.356045  0.558056 -0.429654  0.277140  0.428605  0.406466
# 2   2 -0.260272 -0.949385  1.728538 -0.457986  0.074062  1.419481  0.743511
# 3   3 -0.152152 -0.508959  1.746840 -1.090178  0.249486  1.143312  0.518269
# 4   4 -0.206820 -0.165280  1.527053 -0.448293  0.106125  0.530549  0.658849
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0 -0.130006  0.727159  ... -0.110552  0.217606 -0.134794  0.165959  0.126280
# 1 -0.133118  0.347452  ... -0.194936 -0.605761  0.079469 -0.577395  0.190090
# 2 -0.095576 -0.261297  ... -0.005020  0.702906  0.945045 -1.154666 -0.605564
# 3 -0.065130 -0.205698  ... -0.146927 -0.038212 -0.214048 -1.893131  1.003963
# 4 -0.212660  1.049921  ... -0.106984  0.729727 -0.161666  0.312561 -0.414116
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
data.describe()
# Out:
#                   id            V1            V2            V3            V4  \
# count  568630.000000  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   284314.500000 -7.357466e-17 -1.127612e-16  1.039642e-17 -2.199242e-16
# std    164149.486122  1.000001e+00  1.000001e+00  1.000001e+00  1.000001e+00
# min         0.000000 -3.495584e+00 -4.996657e+01 -3.183760e+00 -4.951222e+00
# 25%    142157.250000 -5.652859e-01 -4.866777e-01 -6.492987e-01 -6.560203e-01
# 50%    284314.500000 -9.363846e-02 -1.358939e-01  3.528579e-04 -7.376152e-02
# 75%    426471.750000  8.326582e-01  3.435552e-01  6.285380e-01  7.070047e-01
# max    568629.000000  2.229046e+00  4.361865e+00  1.412583e+01  3.201536e+00
#
#                  V5            V6            V7            V8            V9  \
# count  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05  5.686300e+05
# mean   4.078595e-17  1.779387e-16  1.691417e-16  1.069632e-17  1.239573e-16
# ...

# %%
data.drop(columns=['id'], inplace=True)

# %%
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])  # Scaling the 'Amount' feature

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=0.95)  # Retain 95% of variance
X_pca = pca.fit_transform(data.drop('Class', axis=1))  # Apply PCA to features excluding the target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_pca, data['Class'], test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
predictions = model.predict(X_test)

# %%
print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     85149
#            1       0.98      0.95      0.96     85440
#
#     accuracy                           0.96    170589
#    macro avg       0.96      0.96      0.96    170589
# weighted avg       0.96      0.96      0.96    170589

# %%
from sklearn.metrics import classification_report, roc_auc_score
print("AUC-ROC:", roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]))
# Out:
# AUC-ROC: 0.9922862650316477

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE

# Load data
data = pd.read_csv('creditcard_2023.csv')

# Data preprocessing
data.drop(columns=['id'], inplace=True)
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Check for missing values
print(data.isnull().sum())

# Apply PCA
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(data.drop('Class', axis=1))

# Visualize PCA explained variance
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
plt.grid(True)
plt.show()

# Split data
X_train, X_test, y_train, y_test = train_test_split(X_pca, data['Class'], test_size=0.3, random_state=42)

# Address class imbalance with SMOTE
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Logistic Regression Model
log_model = LogisticRegression(max_iter=1000)
log_model.fit(X_train_smote, y_train_smote)
log_predictions = log_model.predict(X_test)

# Random Forest Model
rf_model = RandomForestClassifier(random_state=42)
rf_model.fit(X_train_smote, y_train_smote)
rf_predictions = rf_model.predict(X_test)

# Support Vector Machine Model
svm_model = SVC(probability=True, random_state=42)
svm_model.fit(X_train_smote, y_train_smote)
svm_predictions = svm_model.predict(X_test)

# Evaluation Function
def evaluate_model(name, model, X_test, y_test, predictions):
    print(f"=== {name} Model Evaluation ===")
    print(classification_report(y_test, predictions))
    auc_roc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    print(f"AUC-ROC: {auc_roc:.2f}")
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    plt.figure()
    plt.plot(fpr, tpr, label=f'{name} (area = {auc_roc:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve - {name}')
    plt.legend(loc="lower right")
    plt.show()
    cm = confusion_matrix(y_test, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'Confusion Matrix - {name}')
    plt.show()

# Evaluate all models
evaluate_model('Logistic Regression', log_model, X_test, y_test, log_predictions)
evaluate_model('Random Forest', rf_model, X_test, y_test, rf_predictions)
evaluate_model('SVM', svm_model, X_test, y_test, svm_predictions)

# %%
# File path: credit_card_fraud_detection.py

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier

# Load data
data = pd.read_csv('creditcard_2023.csv')

# Data Preprocessing and EDA
data.info()
data.isnull().sum()
data.drop(columns=['id'], inplace=True) 

# Feature scaling
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Handling class imbalance with SMOTE
X = data.drop('Class', axis=1)
y = data['Class']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# PCA Application
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_resampled)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
plt.grid(True)
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_pca, y_resampled, test_size=0.3, random_state=42)

# Model Development and Comparison

# Logistic Regression
log_reg = LogisticRegression(max_iter=1000)
log_reg.fit(X_train, y_train)
log_reg_predictions = log_reg.predict(X_test)
print("Logistic Regression")
print(classification_report(y_test, log_reg_predictions))
print("AUC-ROC:", roc_auc_score(y_test, log_reg.predict_proba(X_test)[:, 1]))
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96     85149
#            1       0.98      0.95      0.96     85440
#
#     accuracy                           0.96    170589
#    macro avg       0.96      0.96      0.96    170589
# weighted avg       0.96      0.96      0.96    170589
#
# AUC-ROC: 0.9922862650316477

# %%
# Random Forest
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)
rf_predictions = rf.predict(X_test)
print("Random Forest")
print(classification_report(y_test, rf_predictions))
print("AUC-ROC:", roc_auc_score(y_test, rf.predict_proba(X_test)[:, 1]))
# Out:
# Random Forest
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# AUC-ROC: 0.999992564944429

# %%
# Neural Network
mlp = MLPClassifier(random_state=42)
mlp.fit(X_train, y_train)
mlp_predictions = mlp.predict(X_test)
print("Neural Network")
print(classification_report(y_test, mlp_predictions))
print("AUC-ROC:", roc_auc_score(y_test, mlp.predict_proba(X_test)[:, 1]))
# Out:
# Neural Network
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85149
#            1       1.00      1.00      1.00     85440
#
#     accuracy                           1.00    170589
#    macro avg       1.00      1.00      1.00    170589
# weighted avg       1.00      1.00      1.00    170589
#
# AUC-ROC: 0.9999555631342512

# %%
# Evaluation and Interpretation

# ROC Curve
models = [('Logistic Regression', log_reg), ('Random Forest', rf), ('Neural Network', mlp)]
plt.figure()
for name, model in models:
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    plt.plot(fpr, tpr, label=f'{name} (area = {roc_auc_score(y_test, model.predict_proba(X_test)[:, 1]):.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

# Confusion Matrix
for name, model in models:
    cm = confusion_matrix(y_test, model.predict(X_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'Confusion Matrix - {name}')
    plt.show()

# %%
# File path: credit_card_fraud_detection.py

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from imblearn.under_sampling import RandomUnderSampler
import time

# Load data
data = pd.read_csv('creditcard_2023.csv')

# Data Preprocessing and EDA
data.info()
data.isnull().sum()
data.drop(columns=['id'], inplace=True) 

# Exploratory Data Analysis
# Visualization of Class distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Class', data=data)
plt.title('Class Distribution')
plt.show()

# Visualization of Amount distribution
plt.figure(figsize=(6,4))
sns.histplot(data['Amount'], bins=50)
plt.title('Transaction Amount Distribution')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12,8))
corr = data.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Feature scaling
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Handling class imbalance with SMOTE
X = data.drop('Class', axis=1)
y = data['Class']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# PCA Application
pca = PCA(n_components=0.95)
X_pca = pca.fit_transform(X_resampled)
plt.figure()
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
plt.grid(True)
plt.show()

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_pca, y_resampled, test_size=0.3, random_state=42)

# Model Development and Comparison
models = {
    'Logistic Regression': LogisticRegression(max_iter=1000),
    'Random Forest': RandomForestClassifier(random_state=42),
    'Neural Network': MLPClassifier(random_state=42)
}

results = {}

for name, model in models.items():
    start_time = time.time()
    model.fit(X_train, y_train)
    train_time = time.time() - start_time
    
    start_time = time.time()
    predictions = model.predict(X_test)
    predict_time = time.time() - start_time
    
    auc_roc = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    report = classification_report(y_test, predictions)
    
    results[name] = {
        'classification_report': report,
        'AUC-ROC': auc_roc,
        'train_time': train_time,
        'predict_time': predict_time
    }
    
    print(f"{name}")
    print(report)
    print(f"AUC-ROC: {auc_roc}")
    print(f"Training Time: {train_time:.4f} seconds")
    print(f"Prediction Time: {predict_time:.4f} seconds")

# Evaluation and Interpretation
plt.figure()
for name, model in models.items():
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    plt.plot(fpr, tpr, label=f'{name} (area = {results[name]["AUC-ROC"]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

for name, model in models.items():
    cm = confusion_matrix(y_test, model.predict(X_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'Confusion Matrix - {name}')
    plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
# File path: credit_card_fraud_detection.py

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import time

# Load data
data = pd.read_csv('creditcard_2023.csv')

# Data Preprocessing and EDA
data.info()
data.isnull().sum()
data.drop(columns=['id'], inplace=True) 

# Exploratory Data Analysis
# Visualization of Class distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Class', data=data)
plt.title('Class Distribution')
plt.show()

# Visualization of Amount distribution
plt.figure(figsize=(6,4))
sns.histplot(data['Amount'], bins=50)
plt.title('Transaction Amount Distribution')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12,8))
corr = data.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Feature scaling and additional feature engineering
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Additional Feature Engineering
# Assuming 'user_id' and 'Merchant_ID' columns exist for demonstration purposes
if 'user_id' in data.columns:
    data['Transaction_Frequency'] = data.groupby('user_id')['Amount'].transform('count')
else:
    data['Transaction_Frequency'] = 1  # Dummy value since user_id does not exist

if 'user_id' in data.columns:
    data['Mean_Transaction_Amount'] = data.groupby('user_id')['Amount'].transform('mean')
else:
    data['Mean_Transaction_Amount'] = data['Amount']  # Using Amount as a dummy mean

if 'Time' in data.columns:
    data['Hour'] = (data['Time'] / 3600).astype(int) % 24
    data['Time_Since_Last_Transaction'] = data.groupby('user_id')['Time'].diff().fillna(0)
else:
    data['Hour'] = 0  # Dummy value since Time does not exist
    data['Time_Since_Last_Transaction'] = 0  # Dummy value since Time does not exist

if 'Merchant_ID' in data.columns:
    data['Merchant_Transaction_Count'] = data.groupby('Merchant_ID')['Amount'].transform('count')
else:
    data['Merchant_Transaction_Count'] = 1  # Dummy value since Merchant_ID does not exist

# Handling class imbalance with SMOTE
X = data.drop('Class', axis=1)
y = data['Class']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# Define a column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('scale', StandardScaler(), ['Amount', 'Transaction_Frequency', 'Mean_Transaction_Amount', 'Hour', 'Time_Since_Last_Transaction', 'Merchant_Transaction_Count'])
    ],
    remainder='passthrough'
)

# Define pipelines
pca = PCA(n_components=0.95)
logistic_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', LogisticRegression(max_iter=1000))
])

random_forest_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', RandomForestClassifier(random_state=42))
])

neural_network_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', MLPClassifier(random_state=42))
])

pipelines = {
    'Logistic Regression (PCA)': logistic_pipeline,
    'Random Forest (PCA)': random_forest_pipeline,
    'Neural Network (PCA)': neural_network_pipeline
}

# Train and evaluate models
results = {}

for name, pipeline in pipelines.items():
    start_time = time.time()
    pipeline.fit(X_train, y_train)
    train_time = time.time() - start_time
    
    start_time = time.time()
    predictions = pipeline.predict(X_test)
    predict_time = time.time() - start_time
    
    auc_roc = roc_auc_score(y_test, pipeline.predict_proba(X_test)[:, 1])
    report = classification_report(y_test, predictions)
    
    results[name] = {
        'classification_report': report,
        'AUC-ROC': auc_roc,
        'train_time': train_time,
        'predict_time': predict_time
    }

# Evaluation and Interpretation
plt.figure()
for name in results:
    fpr, tpr, _ = roc_curve(y_test, pipelines[name].predict_proba(X_test)[:, 1])
    plt.plot(fpr, tpr, label=f'{name} (area = {results[name]["AUC-ROC"]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

for name in results:
    cm = confusion_matrix(y_test, pipelines[name].predict(X_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'Confusion Matrix - {name}')
    plt.show()

# Non-PCA models
logistic_pipeline_no_pca = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', LogisticRegression(max_iter=1000))
])

random_forest_pipeline_no_pca = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier(random_state=42))
])

neural_network_pipeline_no_pca = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', MLPClassifier(random_state=42))
])

pipelines_no_pca = {
    'Logistic Regression': logistic_pipeline_no_pca,
    'Random Forest': random_forest_pipeline_no_pca,
    'Neural Network': neural_network_pipeline_no_pca
}

for name, pipeline in pipelines_no_pca.items():
    start_time = time.time()
    pipeline.fit(X_train, y_train)
    train_time = time.time() - start_time
    
    start_time = time.time()
    predictions = pipeline.predict(X_test)
    predict_time = time.time() - start_time
    
    auc_roc = roc_auc_score(y_test, pipeline.predict_proba(X_test)[:, 1])
    report = classification_report(y_test, predictions)
    
    results[name] = {
        'classification_report': report,
        'AUC-ROC': auc_roc,
        'train_time': train_time,
        'predict_time': predict_time
    }

# Evaluation and Interpretation for non-PCA models
plt.figure()
for name in results:
    if '(PCA)' not in name:
        fpr, tpr, _ = roc_curve(y_test, pipelines_no_pca[name].predict_proba(X_test)[:, 1])
        plt.plot(fpr, tpr, label=f'{name} (area = {results[name]["AUC-ROC"]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

for name in results:
    if '(PCA)' not in name:
        cm = confusion_matrix(y_test, pipelines_no_pca[name].predict(X_test))
        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot()
        plt.title(f'Confusion Matrix - {name}')
        plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...

# %%
# File path: credit_card_fraud_detection.py

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, confusion_matrix, ConfusionMatrixDisplay
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
import time

# Load data
data = pd.read_csv('creditcard_2023.csv')

# Data Preprocessing and EDA
data.info()
data.isnull().sum()
data.drop(columns=['id'], inplace=True) 

# Exploratory Data Analysis
# Visualization of Class distribution
plt.figure(figsize=(6,4))
sns.countplot(x='Class', data=data)
plt.title('Class Distribution')
plt.show()

# Visualization of Amount distribution
plt.figure(figsize=(6,4))
sns.histplot(data['Amount'], bins=50)
plt.title('Transaction Amount Distribution')
plt.show()

# Correlation heatmap
plt.figure(figsize=(12,8))
corr = data.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# Feature scaling and additional feature engineering
scaler = StandardScaler()
data['Amount'] = scaler.fit_transform(data[['Amount']])

# Additional Feature Engineering
# Assuming 'user_id' and 'Merchant_ID' columns exist for demonstration purposes
if 'user_id' in data.columns:
    data['Transaction_Frequency'] = data.groupby('user_id')['Amount'].transform('count')
else:
    data['Transaction_Frequency'] = 1  # Dummy value since user_id does not exist

if 'user_id' in data.columns:
    data['Mean_Transaction_Amount'] = data.groupby('user_id')['Amount'].transform('mean')
else:
    data['Mean_Transaction_Amount'] = data['Amount']  # Using Amount as a dummy mean

if 'Time' in data.columns:
    data['Hour'] = (data['Time'] / 3600).astype(int) % 24
    data['Time_Since_Last_Transaction'] = data.groupby('user_id')['Time'].diff().fillna(0)
else:
    data['Hour'] = 0  # Dummy value since Time does not exist
    data['Time_Since_Last_Transaction'] = 0  # Dummy value since Time does not exist

if 'Merchant_ID' in data.columns:
    data['Merchant_Transaction_Count'] = data.groupby('Merchant_ID')['Amount'].transform('count')
else:
    data['Merchant_Transaction_Count'] = 1  # Dummy value since Merchant_ID does not exist

# Handling class imbalance with SMOTE
X = data.drop('Class', axis=1)
y = data['Class']
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Split the data
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.3, random_state=42)

# Define a column transformer
preprocessor = ColumnTransformer(
    transformers=[
        ('scale', StandardScaler(), ['Amount', 'Transaction_Frequency', 'Mean_Transaction_Amount', 'Hour', 'Time_Since_Last_Transaction', 'Merchant_Transaction_Count'])
    ],
    remainder='passthrough'
)

# Define pipelines
pca = PCA(n_components=0.95)
logistic_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', LogisticRegression(max_iter=1000))
])

random_forest_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', RandomForestClassifier(random_state=42))
])

neural_network_pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('pca', pca),
    ('classifier', MLPClassifier(random_state=42))
])

pipelines = {
    'Logistic Regression (PCA)': logistic_pipeline,
    'Random Forest (PCA)': random_forest_pipeline,
    'Neural Network (PCA)': neural_network_pipeline
}

# Train and evaluate models
results = {}

for name, pipeline in pipelines.items():
    start_time = time.time()
    pipeline.fit(X_train, y_train)
    train_time = time.time() - start_time
    
    start_time = time.time()
    predictions = pipeline.predict(X_test)
    predict_time = time.time() - start_time
    
    auc_roc = roc_auc_score(y_test, pipeline.predict_proba(X_test)[:, 1])
    report = classification_report(y_test, predictions)
    
    results[name] = {
        'classification_report': report,
        'AUC-ROC': auc_roc,
        'train_time': train_time,
        'predict_time': predict_time
    }

# Evaluation and Interpretation
plt.figure()
for name in results:
    fpr, tpr, _ = roc_curve(y_test, pipelines[name].predict_proba(X_test)[:, 1])
    plt.plot(fpr, tpr, label=f'{name} (area = {results[name]["AUC-ROC"]:.2f})')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.show()

for name in results:
    cm = confusion_matrix(y_test, pipelines[name].predict(X_test))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f'Confusion Matrix - {name}')
    plt.show()

# Print the results for each model
for name, result in results.items():
    print(f"{name}\n"
          f"Classification Report:\n{result['classification_report']}\n"
          f"AUC-ROC: {result['AUC-ROC']}\n"
          f"Training Time: {result['train_time']:.4f} seconds\n"
          f"Prediction Time: {result['predict_time']:.4f} seconds\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568630 entries, 0 to 568629
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      568630 non-null  int64
#  1   V1      568630 non-null  float64
#  2   V2      568630 non-null  float64
#  3   V3      568630 non-null  float64
#  4   V4      568630 non-null  float64
#  5   V5      568630 non-null  float64
#  6   V6      568630 non-null  float64
#  7   V7      568630 non-null  float64
#  8   V8      568630 non-null  float64
#  9   V9      568630 non-null  float64
#  10  V10     568630 non-null  float64
#  11  V11     568630 non-null  float64
#  12  V12     568630 non-null  float64
#  13  V13     568630 non-null  float64
#  14  V14     568630 non-null  float64
#  15  V15     568630 non-null  float64
#  16  V16     568630 non-null  float64
#  17  V17     568630 non-null  float64
#  18  V18     568630 non-null  float64
#  19  V19     568630 non-null  float64
# ...
